# %% [markdown]
# <a href="https://colab.research.google.com/github/Letch49/ML_vvsu_2024/blob/master/lab3/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 3

# %% [markdown]
# ##Обработка пропущенных значений

# %% [markdown]
# Обработайте пропущенные значения:
#
#
# * Удалите пропущенные значения
# * Заполните при помощи медианы, среднего для числовых значений
# * Заполните при помощи моды для категориальных значений
# * Интерполируйте
# Выведите статистку после каждого метода и объясните

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Дмитрий/Desktop/ML_VVSU/anime.csv")

df.dropna(inplace=True) #удаление пустых строк
df = df.loc[df['episodes'] != 'Unknown']
df['rating'] = df['rating'].round(1) #округление
df['rating'] = df['rating'].astype(int) #перевод из float в int

df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %%
#Удаление
df_cleaned = df.dropna()
df_cleaned
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %%
#Заполнение при помощи медианы
df_filled_median = df.fillna(df.median())

df_filled_median
# Out:
# C:\Users\Дмитрий\AppData\Local\Temp\ipykernel_17648\1993919372.py:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled_median = df.fillna(df.median())
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %%
#Заполнение при помощи среднего
df_filled_mean = df.fillna(df.mean())

df_filled_mean
# Out:
# C:\Users\Дмитрий\AppData\Local\Temp\ipykernel_17648\3770686863.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled_mean = df.fillna(df.mean())
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %%
#Заполнение при помощи моды
df_filled_mode = df.fillna(df["rating"].mode()[0])

df_filled_mode
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %%
#Заполнение при помощи интерполяции
df_interpolated = df.interpolate()

df_interpolated
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %% [markdown]
# **Объясните**

# %% [markdown]
# ##Поиск выбросов и аномалий

# %% [markdown]
# **Те, кто выполняет задания со * делают поиск выбросов с помощью написанного ранее класса**
#
# Найти выбросы по числовой переменной (использовать метод основанный на среднем и на межквартильном размахе). Объясните результат
#
# Вывести статистику с выбросами и без. Сравните и объясните результат

# %%
import math
from statistics import median, mean
from sklearn.cluster import DBSCAN

class Outline:
  def __init__(self, df):
    self.df = df
  def detect_outline_by_quantile(self, column_name):
        Q1 = self.df[column_name].quantile(0.25)
        Q3 = self.df[column_name].quantile(0.75)
        minimum = Q1 - 1.5 * (Q3 - Q1)
        maximum = Q3 + 1.5 * (Q3 - Q1)
        outliers = self.df[(self.df[column_name] < minimum) | (self.df[column_name] > maximum)]
        return outliers
  def detect_outline_by_mean_std(self,column_name,coef):
        mean = self.df[column_name].mean()
        median = self.df[column_name].median()
        std = self.df[column_name].std()
        n = self.df[column_name].count()
        lower_bound = mean - coef  * std
        upper_bound = mean + coef * std
        outliners = self.df[(self.df[column_name] >= lower_bound) & (self.df[column_name]<=upper_bound)]
        return outliners

# %%
#Методом среднего

so = Outline(df)
outliners = so.detect_outline_by_mean_std("rating",1.5)
print(outliners)
# Out:
#        anime_id                                               name  \
# 603        9252                      Break Blade 3: Kyoujin no Ato
# 604       12893              Danshi Koukousei no Nichijou Specials
# 605        1505  Detective Conan Movie 09: Strategy Above the D...
# 606        4447       Detective Conan Movie 12: Full Score of Fear
# 607         317                 Final Fantasy VII: Advent Children
# ...         ...                                                ...
# 12266      7914                 Kyuukyoku no Chef wa Oishinbo Papa
# 12271      5559                Nijuusou: Wana ni Ochita Onna-tachi
# 12283     29992                               Silent Chaser Kagami
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                              genre     type episodes  rating  \
# 603      Action, Fantasy, Mecha, Military, Shounen    Movie        1       7
# 604         Comedy, School, Shounen, Slice of Life  Special        6       7
# 605    Adventure, Comedy, Mystery, Police, Shounen    Movie        1       7
# 606    Adventure, Comedy, Mystery, Police, Shounen    Movie        1       7
# 607                   Action, Fantasy, Super Power    Movie        1       7
# ...                                            ...      ...      ...     ...
# 12266                                       Hentai      OVA        1       5
# 12271                                       Hentai      OVA        1       5
# 12283                                       Hentai      OVA        1       5
# 12292                                       Hentai      OVA        1       5
# 12293                                       Hentai    Movie        1       5
#
#        members
# 603      42653
# 604      49891
# 605      20347
# 606      19290
# 607     138659
# ...        ...
# 12266      262
# 12271      240
# 12283      112
# 12292      175
# 12293      142
#
# [10237 rows x 7 columns]

# %%
#При помощи межквартильного размаха

so = Outline(df)
outliners = so.detect_outline_by_quantile("rating")
print(outliners)
# Out:
#        anime_id                                name                  genre  \
# 9991      34476  Platonic Chain: Ansatsu Jikkouchuu  Sci-Fi, Slice of Life
# 12258     20007       Hi Gekiga Ukiyoe Senya Ichiya         Action, Hentai
#
#           type episodes  rating  members
# 9991   Special        1       1       51
# 12258    Movie        1       1      129

# %%
#Статистика и объяснение

# %% [markdown]
# **Объяснения**

# %% [markdown]
# ##Дубликаты

# %% [markdown]
# Проверьте датафрейм на дубликаты и удалите их, если дублей нет - создайте.

# %%
#Проверка на дубли
df[df.duplicated ()]
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
#Создание тубелей
df = pd.concat((df, df.iloc[0:100]))
df.describe()
# Out:
#            anime_id        rating       members
# count  11930.000000  11930.000000  1.193000e+04
# mean   13412.284661      6.059765  2.023893e+04
# std    11110.186599      1.070661  6.108775e+04
# min        1.000000      1.000000  1.200000e+01
# 25%     3329.750000      5.000000  2.362500e+02
# 50%     9849.500000      6.000000  1.632500e+03
# 75%    23304.500000      7.000000  1.051525e+04
# max    34519.000000     10.000000  1.013917e+06

# %%
#Удаление дублей
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0           9   200630
# 1           9   793665
# 2           9   114262
# 3           9   673572
# 4           9   151266
# ...       ...      ...
# 12289       4      211
# 12290       4      183
# 12291       4      219
# 12292       5      175
# 12293       5      142
#
# [11830 rows x 7 columns]

# %% [markdown]
# ## Преобразование признаков

# %% [markdown]
# Масштабируйте числовые признаки через MinMaxScaler, StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# MinMax масштабирование
scaler_minmax = MinMaxScaler()
num_features = df.select_dtypes(include=['int64']).columns
df_minmax_scaled = df.copy()
df_minmax_scaled[num_features] = scaler_minmax.fit_transform(df[num_features])
df_minmax_scaled.members.unique()
# Out:
# array([1.97866664e-01, 7.82768603e-01, 1.12683141e-01, ...,
#        2.70232418e-02, 5.65565807e-02, 6.31222846e-04])

# %%
# Standard масштабирование
standard_scaler = StandardScaler()
df_standard_scaler = df.copy()
df_standard_scaler[num_features] = standard_scaler.fit_transform(df[num_features])
df_standard_scaler.members.unique()
# Out:
# array([ 2.95310635, 12.66143319,  1.53921211, ...,  0.11741088,
#         0.60761152, -0.32064947])

# %% [markdown]
# Масштабируйте категориальные признаки через OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# Create an instance of OneHotEncoder
df.name = df.name.astype('category')
df.genre = df.genre.astype('category')
df.type = df.type.astype('category')
encoder = OneHotEncoder()
cat_features = df.select_dtypes(include=['category']).columns
encoder = OneHotEncoder()
df_cat_encoded = pd.get_dummies(df, columns=cat_features, drop_first=True)
encoded_features = encoder.fit_transform(df[cat_features])
encoded_columns = encoder.get_feature_names_out(cat_features)
encoded_columns
# Out:
# array(['name_&quot;0&quot;',
#        'name_&quot;Aesop&quot; no Ohanashi yori: Ushi to Kaeru, Yokubatta Inu',
#        'name_&quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi', ...,
#        'type_OVA', 'type_Special', 'type_TV'], dtype=object)

# %% [markdown]
# ##Задание для гениев*

# %% [markdown]
# Реализовать расчет корреляции Спирмана

# %%
#Функция по расчету тут

# %%
#Пример использования тут и объяснение принципа работы

# %% [markdown]
# ###Пример реализации

# %%
import pandas as pd
import numpy as np


def corr_pearson(column_1, column_2):
  cov = np.cov(column_1, column_2)
  return cov/(column_1.std() * column_2.std())

# %%
data = {
    'Рост': [170, 155, 180, 162, 175],
    'Вес': [65, 50, 75, 55, 70]
}
df = pd.DataFrame(data)
df

# %%
corr_pearson(df["Рост"], df["Вес"])
